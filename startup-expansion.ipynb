# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
startups = pd.read_excel("C:/Users/Ahmed/Downloads/New folder/startup-expansion.xlsx")
startups
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
startups[['Marketing Spend','Revenue']].describe().round(2)
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %%
# startups[['Marketing Spend','Revenue']].describe().round(2)

# %%
startups.isna().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
startups.duplicated().sum()
# Out:
# 0

# %%
startups['Marketing Spend'].nlargest(5)
# Out:
# 86     3984
# 62     3924
# 69     3697
# 23     3679
# 146    3675
# Name: Marketing Spend, dtype: int64

# %%
startups[startups['Marketing Spend']== startups['Marketing Spend'].min() ]
# Out:
#      Store ID       City       State Sales Region New Expansion  \
# 135       136  San Mateo  California     Region 2           Old
#
#      Marketing Spend  Revenue
# 135             1811    19426

# %%
sns.boxplot(startups['Marketing Spend'])
# Out:
# <Axes: >

# %%
# sns.boxplot(startups[startups['Marketing Spend']<3900]['Marketing Spend'])

# %%
plt.figure(figsize=(2,2))
startups['Sales Region'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sales Region'>

# %%
print(startups['City'].unique())
startups['City'].nunique()
# Out:
# ['Peoria' 'Midland' 'Spokane' 'Denton' 'Overland Park' 'Yonkers'
#  'Birmingham' 'Antioch' 'Worcester' 'Rochester' 'Rialto' 'Santa Maria'
#  'Las Cruces' 'Jackson' 'Hillsboro' 'Temecula' 'Tallahassee' 'Fontana'
#  'Kent' 'Broken Arrow' 'Concord' 'Modesto' 'Montgomery' 'Burbank'
#  'Elk Grove' 'Port St. Lucie' 'Elizabeth' 'Salt Lake City' 'Waco' 'Edison'
#  'Boulder' 'Grand Rapids' 'Tyler' 'Charleston' 'Huntsville' 'Pearland'
#  'Inglewood' 'Oxnard' 'Miramar' 'Cape Coral' 'Syracuse' 'Newport News'
#  'Lewisville' 'Carrollton' 'San Bernardino' 'Pasadena' 'Roseville'
#  'Murrieta' 'San Angelo' 'Olathe' 'Akron' 'Fullerton' 'Manchester'
#  'Everett' 'West Covina' 'Thornton' 'Hampton' 'Waterbury' 'Ventura'
#  'Davenport' 'Columbia' 'Simi Valley' 'Richmond' 'Little Rock' 'El Cajon'
#  'Santa Clara' 'Oceanside' 'Davie' 'Lakeland' 'Centennial' 'Lowell'
#  'Ontario' 'Palm Bay' 'Murfreesboro' 'Vancouver' 'Topeka'
#  'West Valley City' 'New Haven' 'Pueblo' 'Costa Mesa' 'Garden Grove'
# ...

# %%
print(startups['State'].unique())
startups['State'].nunique()
# Out:
# ['Arizona' 'Texas' 'Washington' 'Kansas' 'New York' 'Alabama' 'California'
#  'Massachusetts' 'New Mexico' 'Mississippi' 'Oregon' 'Florida' 'Oklahoma'
#  'New Jersey' 'Utah' 'Colorado' 'Michigan' 'South Carolina' 'Virginia'
#  'Ohio' 'New Hampshire' 'Connecticut' 'Iowa' 'Arkansas' 'Tennessee'
#  'North Carolina' 'Georgia' 'Illinois' 'Montana' 'Indiana' 'South Dakota'
#  'Louisiana' 'Minnesota' 'Wisconsin' 'Rhode Island']
# 35

# %%
startups.sample(10)
# Out:
#      Store ID              City           State Sales Region New Expansion  \
# 85         86           Gresham          Oregon     Region 2           Old
# 13         14           Jackson     Mississippi     Region 1           Old
# 63         64       Little Rock        Arkansas     Region 2           Old
# 6           7        Birmingham         Alabama     Region 1           Old
# 91         92           Augusta         Georgia     Region 1           Old
# 111       112   West Palm Beach         Florida     Region 1           Old
# 87         88        High Point  North Carolina     Region 1           Old
# 17         18           Fontana      California     Region 2           Old
# 82         83  North Charleston  South Carolina     Region 1           Old
# 133       134         Green Bay       Wisconsin     Region 1           Old
#
#      Marketing Spend  Revenue
# 85              2745    19708
# 13              3466    54701
# 63              2440    68828
# ...

# %%
startups['profit']=startups['Revenue']-startups['Marketing Spend']

# %%
startups.head()
# Out:
#    Store ID           City       State Sales Region New Expansion  \
# 0         1         Peoria     Arizona     Region 2           Old
# 1         2        Midland       Texas     Region 2           Old
# 2         3        Spokane  Washington     Region 2           Old
# 3         4         Denton       Texas     Region 2           Old
# 4         5  Overland Park      Kansas     Region 2           Old
#
#    Marketing Spend  Revenue  profit   Ro_MS
# 0             2601    48610   46009  1769.0
# 1             2727    45689   42962  1575.0
# 2             2768    49554   46786  1690.0
# 3             2759    38284   35525  1288.0
# 4             2869    59887   57018  1987.0

# %% [markdown]
# ##### ROI = (profit /investment cost )*100      ### ROI Return on investment

# %%
startups['Ro_MS'] = round((startups['profit']/startups['Marketing Spend']),2)*100

# %%
startups
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  profit   Ro_MS
# 0               2601    48610   46009  1769.0
# ...

# %%
startups['Ro_MS%'] = round((startups['profit']/startups['Marketing Spend']),2)
startups
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  profit   Ro_MS  Ro_MS%
# 0               2601    48610   46009  1769.0   17.69
# ...

# %%
plt.bar(startups['Sales Region'], startups['profit']) 
plt.show()

# %%
startups['Sales Region'].value_counts()
# Out:
# Sales Region
# Region 2    86
# Region 1    64
# Name: count, dtype: int64

# %%
startups[startups['New Expansion']== 'Old']['Sales Region'].value_counts()
# Out:
# Sales Region
# Region 2    79
# Region 1    61
# Name: count, dtype: int64

# %%
plt.bar(startups['New Expansion'], startups['profit']) 
plt.show()

# %%
startups.to_csv('startup-expansion-analysis.csv')
